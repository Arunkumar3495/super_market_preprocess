# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/supermarket_sales - Sheet1.csv')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df['Date'][0]
# Out:
# '1/5/2019'

# %%
 type(df['Date'][0])
# Out:
# str

# %%
from pandas import to_datetime

# %%
df['Date'] = to_datetime(df['Date'])

# %%
 type(df['Date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['Time'] = to_datetime(df['Time'])

# %%
 df['Time'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df['Date']
# Out:
# 0     2019-01-05
# 1     2019-03-08
# 2     2019-03-03
# 3     2019-01-27
# 4     2019-02-08
#          ...
# 995   2019-01-29
# 996   2019-03-02
# 997   2019-02-09
# 998   2019-02-22
# 999   2019-02-18
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
def fetch_att(x):
  day = x.day
  month = x.month
  year = x.year
  return [day,month,year]

# %%
df['Date'].apply(fetch_att)
# Out:
# 0       [5, 1, 2019]
# 1       [8, 3, 2019]
# 2       [3, 3, 2019]
# 3      [27, 1, 2019]
# 4       [8, 2, 2019]
#            ...
# 995    [29, 1, 2019]
# 996     [2, 3, 2019]
# 997     [9, 2, 2019]
# 998    [22, 2, 2019]
# 999    [18, 2, 2019]
# Name: Date, Length: 1000, dtype: object

# %%
def fetch_att(x):
  day = x.day
  month = x.month
  year = x.year
  return pd.Series([day,month,year])

# %%
# df['Date'].apply(fetch_att)
df[['day','month','year']] = df['Date'].apply(fetch_att)

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#                  Time      Payment    cogs  gross margin percentage  \
# 0 2023-09-28 13:08:00      Ewallet  522.83                 4.761905
# ...

# %%
df['Time'][0]
# Out:
# Timestamp('2023-09-28 13:08:00')

# %%
type(df['Time'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['Time'][0].hr

# %%
df['hour'] = df['Time'].apply(lambda x:x.hour)

# %%
df.head(1)
# Out:
#     Invoice ID Branch    City Customer type  Gender       Product line  \
# 0  750-67-8428      A  Yangon        Member  Female  Health and beauty
#
#    Unit price  Quantity   Tax 5%     Total  ...                Time  Payment  \
# 0       74.69         7  26.1415  548.9715  ... 2023-09-28 13:08:00  Ewallet
#
#      cogs  gross margin percentage  gross income  Rating  day  month  year  \
# 0  522.83                 4.761905       26.1415     9.1    5      1  2019
#
#    hour
# 0    13
#
# [1 rows x 21 columns]

# %%
df['Time'][0].split(' ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-1dfafac6f274> in <cell line: 1>()
# ----> 1 df['Time'][0].split(' ')
#
# AttributeError: 'Timestamp' object has no attribute 'split'

# %%
df['Time'][0]
# Out:
# Timestamp('2023-09-28 13:08:00')

# %%
type('2023-09-28 13:08:00')
# Out:
# str

# %%
'2023-09-28 13:08:00'.split(' ')
# Out:
# ['2023-09-28', '13:08:00']

# %%
'2023-09-28 13:08:00'.split(' ')[1]
# Out:
# '13:08:00'

# %%
'2023-09-28 13:08:00'.split(' ')[1].split(':')[0]
# Out:
# '13'

# %%
int('2023-09-28 13:08:00'.split(' ')[1].split(':')[0])
# Out:
# 13

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating          day  \
# count              1000.000000   1000.000000  1000.00000  1000.000000
# mean                  4.761905     15.379369     6.97270    15.256000
# std                   0.000000     11.708825     1.71858     8.693563
# ...

# %%
df.describe().T
# Out:
#                           count         mean         std          min  \
# Unit price               1000.0    55.672130   26.494628    10.080000
# Quantity                 1000.0     5.510000    2.923431     1.000000
# Tax 5%                   1000.0    15.379369   11.708825     0.508500
# Total                    1000.0   322.966749  245.885335    10.678500
# cogs                     1000.0   307.587380  234.176510    10.170000
# gross margin percentage  1000.0     4.761905    0.000000     4.761905
# gross income             1000.0    15.379369   11.708825     0.508500
# Rating                   1000.0     6.972700    1.718580     4.000000
# day                      1000.0    15.256000    8.693563     1.000000
# month                    1000.0     1.993000    0.835254     1.000000
# year                     1000.0  2019.000000    0.000000  2019.000000
# hour                     1000.0    14.910000    3.186857    10.000000
#
# ...

# %%
plt.figure(figsize=(14,8))
sns.heatmap(np.round(df.corr(),2),annot = True)
# Out:
# <ipython-input-44-1fe08fa0a51f>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(np.round(df.corr(),2),annot = True)
# <Axes: >

# %%
sns.scatterplot(x = 'Tax 5%',y = 'gross income',data = df)
# Out:
# <Axes: xlabel='Tax 5%', ylabel='gross income'>

# %%
sns.scatterplot(x='Quantity',y = 'cogs',data = df)
# Out:
# <Axes: xlabel='Quantity', ylabel='cogs'>

# %%
sns.regplot(x='Quantity',y = 'cogs',data = df)
# Out:
# <Axes: xlabel='Quantity', ylabel='cogs'>

# %%
# Out:
# <Axes: xlabel='month', ylabel='day'>
